# %% [markdown]
# <a href="https://colab.research.google.com/github/Maffyo/Maffyo/blob/main/Keep_Updating.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install setuptools
# !pip install packaging
# !pip install pandas dash
# !pip3 install httpx==0.20 dash plotly

# %%
import pandas as pd
import dash
from dash import html, dcc
from dash.dependencies import Input, Output, State
import plotly.graph_objects as go
import plotly.express as px
from dash import no_update
import datetime as dt

# %%
Car_sales =  pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/historical_automobile_sales.csv")

# %%
Car_sales.head()
# Out:
#         Date  Year Month  Recession  Consumer_Confidence  Seasonality_Weight  \
# 0  1/31/1980  1980   Jan          1               108.24                0.50
# 1  2/29/1980  1980   Feb          1                98.75                0.75
# 2  3/31/1980  1980   Mar          1               107.48                0.20
# 3  4/30/1980  1980   Apr          1               115.01                1.00
# 4  5/31/1980  1980   May          1                98.72                0.20
#
#        Price  Advertising_Expenditure  Competition     GDP  Growth_Rate  \
# 0  27483.571                     1558            7  60.223     0.010000
# 1  24308.678                     3048            4  45.986    -0.309594
# 2  28238.443                     3137            3  35.141    -0.308614
# 3  32615.149                     1653            7  45.673     0.230596
# 4  23829.233                     1319            4  52.997     0.138197
#
#    unemployment_rate  Automobile_Sales     Vehicle_Type        City
# ...

# %%
year_list = [i for i in range(1980, 2024, 1)]

# %%
app = dash.Dash(__name__)

app.layout = html.Div(children=[
    html.H1('Automobile Sales Statistics Dashboard', style={'textAlign': 'center', 'color': '#503D36', 'font-size': 24})


])

if __name__ == '__main__':
    app.run_server()

# %%
app = dash.Dash(__name__)

app.layout = html.Div(children= [
    html.H1('Automobile Sales Statistics Dashboard', style={'textAlign': 'center', 'color': '#503D36', 'font-size': 24}),

    dcc.Dropdown(id='dropdown-statistics',
                   options=[
                           {'label': 'Yearly Statistics', 'value': 'Yearly Statistics'},
                           {'label': 'Recession Period Statistics', 'value': 'Recession Period Statistics'}
                           ],
                  placeholder='Select a report type')
])

if __name__ == '__main__':
    app.run_server()

# %%
app = dash.Dash(__name__)

app.layout = html.Div(children= [
    html.H1('Automobile Sales Statistics Dashboard', style={'textAlign': 'center', 'color': '#503D36', 'font-size': 24}),

    dcc.Dropdown(id='dropdown-statistics',
                   options=[
                           {'label': 'Yearly Statistics', 'value': 'Yearly Statistics'},
                           {'label': 'Recession Period Statistics', 'value': 'Recession Period Statistics'}
                           ],
                  placeholder='Select a report type'),
          dcc.Dropdown(id='select-year',
                       options=[{'label': i, 'value': i} for i in year_list],
                       placeholder='Select Year')
])

if __name__ == '__main__':
    app.run_server()

# %%
app = dash.Dash(__name__)

app.layout = html.Div(children= [
    html.H1('Automobile Sales Statistics Dashboard', style={'textAlign': 'center', 'color': '#503D36', 'font-size': 24}),

    dcc.Dropdown(id='dropdown-statistics',
                   options=[
                           {'label': 'Yearly Statistics', 'value': 'Yearly Statistics'},
                           {'label': 'Recession Period Statistics', 'value': 'Recession Period Statistics'}
                           ],
                  placeholder='Select a report type'),
          dcc.Dropdown(id='select-year',
                       options=[{'label': i, 'value': i} for i in year_list],
                       placeholder='Select Year'),
    html.Div([
    html.Div(id='output-container', className='chart-grid', style={'display': 'flex'}),
])
])

if __name__ == '__main__':
    app.run_server()

# %%
app = dash.Dash(__name__)

app.layout = html.Div(children=[
    html.H1('Automobile Sales Statistics Dashboard', style={'textAlign': 'center', 'color': '#503D36', 'font-size': 24}),

    dcc.Dropdown(id='dropdown-statistics',
                 options=[
                     {'label': 'Yearly Statistics', 'value': 'Yearly_Statistics'},
                     {'label': 'Recession Period Statistics', 'value': 'Recession_Period_Statistics'}
                 ],
                 placeholder='Select a report type'),

    dcc.Dropdown(id='select-year',
                 options=[{'label': i, 'value': i} for i in year_list],
                 placeholder='Select Year'),

    html.Div([
        html.Div(id='output-container', className='chart-grid', style={'display': 'flex'}),
    ])
])

def compute_info(Car_sales, Yearly_Statistics):
    yearly = Car_sales[Car_sales['Year'] == int(year_list)]
    avg_yearly_sales = yearly.groupby(['Year'])['Automobile_Sales'].mean().reset_index()
    total_monthly_sales = yearly.groupby(['Month'])['Automobile_Sales'].sum()
    vehicle_sales = yearly.groupby(['Year','Vehicle_Type'], as_index=False)['Automobile_Sales'].mean().reset_index()
    vehicle_advertising = yearly.groupby('Vehicle_Type')['Advertising_Expenditure'].sum()
    return avg_yearly_sales, total_monthly_sales, vehicle_sales, vehicle_advertising

def compute_info(Car_sales, Recession_Period_Statistics):
    rec_data = Car_sales[Car_sales['Recession'] == 1]
    avg_rec_sale = rec_data.groupby('Recession')['Automobile_Sales'].mean()
    avg_vehicle_type_sale = rec_data.groupby('Vehicle_Type')['Automobile_Sales'].mean()
    vehicle_type_advertisement = rec_data.groupby('Vehicle_Type')['Advertising_Expenditure'].sum()
    vehicle_type_unemployment = rec_data.groupby(['Vehicle_Type', 'unemployment_rate'])['Automobile_Sales'].mean()
    return avg_rec_sale, avg_vehicle_type_sale, vehicle_type_advertisement, vehicle_type_unemployment

if __name__ == '__main__':
    app.run_server()

# %%
app = dash.Dash(__name__)

app.layout = html.Div(children=[
    html.H1('Automobile Sales Statistics Dashboard', style={'textAlign': 'center', 'color': '#503D36', 'font-size': 24}),

    dcc.Dropdown(id='dropdown-statistics',
                 options=[
                     {'label': 'Yearly Statistics', 'value': 'Yearly_Statistics'},
                     {'label': 'Recession Period Statistics', 'value': 'Recession_Period_Statistics'}
                 ],
                 placeholder='Select a report type'),

    dcc.Dropdown(id='select-year',
                 options=[{'label': i, 'value': i} for i in year_list],
                 placeholder='Select Year'),

    html.Div([
        html.Div(id='output-container', className='chart-grid', style={'display': 'flex'}),
    ])
])

def compute_info(Car_sales, Yearly_Statistics):
    yearly = Car_sales[Car_sales['Year'] == int(year_list)]
    avg_yearly_sales = yearly.groupby(['Year'])['Automobile_Sales'].mean().reset_index()
    total_monthly_sales = yearly.groupby(['Month'])['Automobile_Sales'].sum()
    vehicle_sales = yearly.groupby(['Year','Vehicle_Type'], as_index=False)['Automobile_Sales'].mean().reset_index()
    vehicle_advertising = yearly.groupby('Vehicle_Type')['Advertising_Expenditure'].sum()
    return avg_yearly_sales, total_monthly_sales, vehicle_sales, vehicle_advertising

def compute_info(Car_sales, Recession_Period_Statistics):
    rec_data = Car_sales[Car_sales['Recession'] == 1]
    avg_rec_sale = rec_data.groupby('Recession')['Automobile_Sales'].mean()
    avg_vehicle_type_sale = rec_data.groupby('Vehicle_Type')['Automobile_Sales'].mean()
    vehicle_type_advertisement = rec_data.groupby('Vehicle_Type')['Advertising_Expenditure'].sum()
    vehicle_type_unemployment = rec_data.groupby(['Vehicle_Type', 'unemployment_rate'])['Automobile_Sales'].mean()
    return avg_rec_sale, avg_vehicle_type_sale, vehicle_type_advertisement, vehicle_type_unemployment

@app.callback(
    Output(component_id='output-container', component_property='children'),
    [Input(component_id='select-year', component_property='value'),
     Input(component_id='dropdown-statistics', component_property='value')]
)
def update_input_container(selected_year, selected_statistic):
    if selected_statistic == 'Yearly_Statistics':
        return compute_info(Car_sales, selected_year)
    else:
        return compute_info(Car_sales, selected_statistic)

if __name__ == '__main__':
    app.run_server()

# %%
app = dash.Dash(__name__)

app.layout = html.Div(children=[
    html.H1('Automobile Sales Statistics Dashboard', style={'textAlign': 'center', 'color': '#503D36', 'font-size': 24}),

    dcc.Dropdown(id='dropdown-statistics',
                 options=[
                     {'label': 'Yearly Statistics', 'value': 'Yearly_Statistics'},
                     {'label': 'Recession Period Statistics', 'value': 'Recession_Period_Statistics'}
                 ],
                 placeholder='Select a report type'),

    dcc.Dropdown(id='select-year',
                 options=[{'label': i, 'value': i} for i in year_list],
                 placeholder='Select Year'),

    html.Div([
        html.Div(id='output-container', className='chart-grid', style={'display': 'flex'}),
    ])
])

def compute_info(Car_sales, Yearly_Statistics):
    yearly = Car_sales[Car_sales['Year'] == int(Yearly_Statistics)]
    avg_yearly_sales = yearly.groupby(['Year'])['Automobile_Sales'].mean().reset_index()
    total_monthly_sales = yearly.groupby(['Month'])['Automobile_Sales'].sum()
    vehicle_sales = yearly.groupby(['Year','Vehicle_Type'], as_index=False)['Automobile_Sales'].mean().reset_index()
    vehicle_advertising = yearly.groupby('Vehicle_Type')['Advertising_Expenditure'].sum()
    return avg_yearly_sales, total_monthly_sales, vehicle_sales, vehicle_advertising

def compute_recession_info(Car_sales):
    rec_data = Car_sales[Car_sales['Recession'] == 1]
    avg_rec_sale = rec_data.groupby('Recession')['Automobile_Sales'].mean()
    avg_vehicle_type_sale = rec_data.groupby('Vehicle_Type')['Automobile_Sales'].mean()
    vehicle_type_advertisement = rec_data.groupby('Vehicle_Type')['Advertising_Expenditure'].sum()
    vehicle_type_unemployment = rec_data.groupby(['Vehicle_Type', 'unemployment_rate'])['Automobile_Sales'].mean()
    return avg_rec_sale, avg_vehicle_type_sale, vehicle_type_advertisement, vehicle_type_unemployment

@app.callback(
    Output(component_id='output-container', component_property='children'),
    [Input(component_id='select-year', component_property='value'),
     Input(component_id='dropdown-statistics', component_property='value')]
)
def update_input_container(selected_year, selected_statistic):
    if selected_statistic == 'Yearly_Statistics':
        return compute_info(Car_sales, selected_year)
    else:
        return compute_recession_info(Car_sales)

def update_output_container(selected_statistic, Car_sales):
    if selected_statistic == 'Recession_Period_Statistics':
        # Filter the data for recession periods
        recession_data = Car_sales[Car_sales['Recession'] == 1]
        # Add your logic for updating the output container based on recession data

if __name__ == '__main__':
    app.run_server()

# %%
app = dash.Dash(__name__)

Car_sales =  pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/historical_automobile_sales.csv")
app.layout = html.Div(children=[
    html.H1('Automobile Sales Statistics Dashboard', style={'textAlign': 'center', 'color': '#503D36', 'font-size': 24}),

    dcc.Dropdown(id='dropdown-statistics', value = 'Yearly_Statistics',
                 options=[
                     {'label': 'Yearly Statistics', 'value': 'Yearly_Statistics'},
                     {'label': 'Recession Period Statistics', 'value': 'Recession_Period_Statistics'}
                 ],
                 placeholder='Select a report type'),

    dcc.Dropdown(id='select-year', value = 2010,
                 options=[{'label': i, 'value': i} for i in year_list],
                 placeholder='Select Year'),

    html.Div([
        html.Div(id='output-container', className='chart-grid', style={'display': 'flex'}),
    ])
])

def compute_info(Car_sales, Yearly_Statistics):
    yearly = Car_sales[Car_sales['Year'] == int(Yearly_Statistics)]
    avg_yearly_sales = yearly.groupby(['Year'])['Automobile_Sales'].mean().reset_index()
    total_monthly_sales = yearly.groupby(['Month'])['Automobile_Sales'].sum().reset_index()
    vehicle_sales = yearly.groupby(['Year','Vehicle_Type'], as_index=False)['Automobile_Sales'].mean().reset_index()
    vehicle_advertising = yearly.groupby('Vehicle_Type')['Advertising_Expenditure'].sum().reset_index()
    return avg_yearly_sales, total_monthly_sales, vehicle_sales, vehicle_advertising

def compute_recession_info(Car_sales):
    rec_data = Car_sales[Car_sales['Recession'] == 1]
    avg_rec_sale = rec_data.groupby('Recession')['Automobile_Sales'].mean().reset_index()
    avg_vehicle_type_sale = rec_data.groupby('Vehicle_Type')['Automobile_Sales'].mean().reset_index()
    vehicle_type_advertisement = rec_data.groupby('Vehicle_Type')['Advertising_Expenditure'].sum().reset_index()
    vehicle_type_unemployment = rec_data.groupby(['Vehicle_Type', 'unemployment_rate'])['Automobile_Sales'].mean().reset_index()
    return avg_rec_sale, avg_vehicle_type_sale, vehicle_type_advertisement, vehicle_type_unemployment

@app.callback(
    Output(component_id='output-container', component_property='children'),
    [Input(component_id='select-year', component_property='value'),
     Input(component_id='dropdown-statistics', component_property='value')]
)
def update_input_container(selected_year, selected_statistic):
    if selected_statistic == 'Yearly_Statistics':
        return get_graph(selected_year)
    elif selected_statistic == 'Recession_Period_Statistics':
        return get_recession_graph()

def get_graph(Yearly_Statistics):
    avg_yearly_sales, total_monthly_sales, vehicle_sales, vehicle_advertising = compute_info(Car_sales, Yearly_Statistics)

    R_chart1 = dcc.Graph(figure=px.line(avg_yearly_sales,
                                        x='Year',
                                        y='Automobile_Sales',
                                        title="Yearly Average Automobile sales"))
    R_chart2 = dcc.Graph(figure=px.line(total_monthly_sales,
                                        x='Month',
                                        y='Automobile_Sales',
                                        title="Total Monthly Automobile sales"))
    R_chart3 = dcc.Graph(figure=px.bar(vehicle_sales,
                                        x='Month',
                                        y='Automobile_Sales',
                                        title="Average Monthly Automobile sales"))
    R_chart4 = dcc.Graph(figure=px.pie(vehicle_advertising,
                                       values='Advertising_Expenditure',
                                       names='Vehicle_Type',
                                       title="Total Advertisement Expenditure"
                                      )
                        )

    return [
        html.Div(className='chart-item', children=[R_chart1, R_chart2]),
        html.Div(className='chart-item', children=[R_chart3, R_chart4])
    ]

def get_recession_graph():
    avg_rec_sale, avg_vehicle_type_sale, vehicle_type_advertisement, vehicle_type_unemployment = compute_recession_info(Car_sales)

    r_chart1 = dcc.Graph(figure=px.line(avg_rec_sale,
                                        x='Recession',
                                        y='Automobile_Sales',
                                        title="Average Automobile sales during Recession"))
    r_chart2 = dcc.Graph(figure=px.bar(avg_vehicle_type_sale,
                                        x='Vehicle_Type',
                                        y='Automobile_Sales',
                                        title="Average number of vehicles sold during Recession"))
    r_chart3 = dcc.Graph(figure=px.bar(vehicle_type_unemployment,
                                        x='Vehicle_Type',
                                        y='Automobile_Sales',
                                        title="Effect of unemployment rate on vehicle type during Recession"))
    r_chart4 = dcc.Graph(figure=px.pie(vehicle_type_advertisement,
                                       values='Advertising_Expenditure',
                                       names='Vehicle_Type',
                                       title="Total Advertisement Expenditure during Recession"
                                      )
                        )

    return [
        html.Div(className='chart-item', children=[r_chart1, r_chart2]),
        html.Div(className='chart-item', children=[r_chart3, r_chart4])
    ]

if __name__ == '__main__':
    app.run_server()

# %%
app = dash.Dash(__name__)

app.layout = html.Div(children=[
    html.H1('Automobile Sales Statistics Dashboard', style={'textAlign': 'center', 'color': '#503D36', 'font-size': 24}),

    dcc.Dropdown(id='dropdown-statistics', value='Yearly_Statistics',
                 options=[
                     {'label': 'Yearly Statistics', 'value': 'Yearly_Statistics'},
                     {'label': 'Recession Period Statistics', 'value': 'Recession_Period_Statistics'}
                 ],
                 placeholder='Select a report type'),

    dcc.Dropdown(id='select-year', value=2010,
                 options=[{'label': i, 'value': i} for i in Car_sales['Year'].unique()],
                 placeholder='Select Year'),

    html.Div([
        html.Div(id='output-container', className='chart-grid', style={'display': 'flex'}),
    ])
])

def compute_info(Car_sales, Yearly_Statistics):
    yearly = Car_sales[Car_sales['Year']]
    avg_yearly_sales = yearly.groupby(['Year'])['Automobile_Sales'].mean().reset_index()
    total_monthly_sales = yearly.groupby(['Month'])['Automobile_Sales'].sum().reset_index()
    vehicle_sales = yearly.groupby(['Year','Vehicle_Type'], as_index=False)['Automobile_Sales'].mean().reset_index()
    vehicle_advertising = yearly.groupby('Vehicle_Type')['Advertising_Expenditure'].sum().reset_index()
    return avg_yearly_sales, total_monthly_sales, vehicle_sales, vehicle_advertising

def compute_recession_info(Car_sales):
    rec_data = Car_sales[Car_sales['Recession'] == 1]
    avg_rec_sale = rec_data.groupby(['Recession', 'Year'])['Automobile_Sales'].mean().reset_index()
    avg_vehicle_type_sale = rec_data.groupby('Vehicle_Type')['Automobile_Sales'].mean().reset_index()
    vehicle_type_advertisement = rec_data.groupby('Vehicle_Type')['Advertising_Expenditure'].sum().reset_index()
    vehicle_type_unemployment = rec_data.groupby(['Vehicle_Type', 'unemployment_rate'])['Automobile_Sales'].mean().reset_index()
    return avg_rec_sale, avg_vehicle_type_sale, vehicle_type_advertisement, vehicle_type_unemployment

@app.callback(
    Output(component_id='output-container', component_property='children'),
    [Input(component_id='select-year', component_property='value'),
     Input(component_id='dropdown-statistics', component_property='value')]
)
def update_input_container(selected_year, selected_statistic):
    if selected_statistic == 'Yearly_Statistics':
        return get_graph(selected_year)
    elif selected_statistic == 'Recession_Period_Statistics':
        return get_recession_graph()

def get_graph(Yearly_Statistics):
    avg_yearly_sales, total_monthly_sales, vehicle_sales, vehicle_advertising = compute_info(Car_sales, Yearly_Statistics)

    R_chart1 = dcc.Graph(figure=px.line(avg_yearly_sales,
                                        x='Year',
                                        y='Automobile_Sales',
                                        title="Yearly Average Automobile sales"))
    R_chart2 = dcc.Graph(figure=px.line(total_monthly_sales,
                                        x='Month',
                                        y='Automobile_Sales',
                                        title="Total Monthly Automobile sales"))
    R_chart3 = dcc.Graph(figure=px.bar(vehicle_sales,
                                        x='Month',
                                        y='Automobile_Sales',
                                        title="Average Monthly Automobile sales"))
    R_chart4 = dcc.Graph(figure=px.pie(vehicle_advertising,
                                       values='Advertising_Expenditure',
                                       names='Vehicle_Type',
                                       title="Total Advertisement Expenditure"
                                      )
                        )

    return [
        html.Div(className='chart-item', children=[R_chart1, R_chart2]),
        html.Div(className='chart-item', children=[R_chart3, R_chart4])
    ]

def get_recession_graph():
    avg_rec_sale, avg_vehicle_type_sale, vehicle_type_advertisement, vehicle_type_unemployment = compute_recession_info(Car_sales)

    r_chart1 = dcc.Graph(figure=px.line(avg_rec_sale,
                                        x='Year',
                                        y='Automobile_Sales',
                                        title="Average Automobile sales during Recession"))
    r_chart2 = dcc.Graph(figure=px.bar(avg_vehicle_type_sale,
                                        x='Vehicle_Type',
                                        y='Automobile_Sales',
                                        title="Average number of vehicles sold during Recession"))
    r_chart3 = dcc.Graph(figure=px.bar(vehicle_type_unemployment,
                                        x='Vehicle_Type',
                                        y='Automobile_Sales',
                                        title="Effect of unemployment rate on vehicle type during Recession"))
    r_chart4 = dcc.Graph(figure=px.pie(vehicle_type_advertisement,
                                       values='Advertising_Expenditure',
                                       names='Vehicle_Type',
                                       title="Total Advertisement Expenditure during Recession"
                                      )
                        )

    return [
        html.Div(className='chart-item', children=[r_chart1, r_chart2]),
        html.Div(className='chart-item', children=[r_chart3, r_chart4])
    ]

if __name__ == '__main__':
    app.run_server()

# %%
app = dash.Dash(__name__)

app.layout = html.Div(children=[
    html.H1('Automobile Sales Statistics Dashboard', style={'textAlign': 'center', 'color': '#503D36', 'font-size': 24}),

    dcc.Dropdown(id='dropdown-statistics', value='Yearly_Statistics',
                 options=[
                     {'label': 'Yearly Statistics', 'value': 'Yearly_Statistics'},
                     {'label': 'Recession Period Statistics', 'value': 'Recession_Period_Statistics'}
                 ],
                 placeholder='Select a report type'),

    dcc.Dropdown(id='select-year', value=2010,
                 options=[{'label': i, 'value': i} for i in Car_sales['Year'].unique()],
                 placeholder='Select Year'),

    html.Div([
        html.Div(id='output-container', className='chart-grid', style={'display': 'flex'}),
    ])
])

def compute_info(Car_sales, selected_year):
    yearly = Car_sales[Car_sales['Year'] == selected_year]
    avg_yearly_sales = yearly.groupby(['Year', 'Vehicle_Type'])['Automobile_Sales'].mean().reset_index()
    total_monthly_sales = yearly.groupby(['Month'])['Automobile_Sales'].sum().reset_index()
    vehicle_sales = yearly.groupby(['Month', 'Vehicle_Type'])['Automobile_Sales'].mean().reset_index()
    vehicle_advertising = yearly.groupby('Vehicle_Type')['Advertising_Expenditure'].sum().reset_index()
    return avg_yearly_sales, total_monthly_sales, vehicle_sales, vehicle_advertising

def compute_recession_info(Car_sales):
    rec_data = Car_sales[Car_sales['Recession'] == 1]
    avg_rec_sale = rec_data.groupby(['Recession', 'Year'])['Automobile_Sales'].mean().reset_index()
    avg_vehicle_type_sale = rec_data.groupby('Vehicle_Type')['Automobile_Sales'].mean().reset_index()
    vehicle_type_advertisement = rec_data.groupby('Vehicle_Type')['Advertising_Expenditure'].sum().reset_index()
    vehicle_type_unemployment = rec_data.groupby(['Vehicle_Type', 'unemployment_rate'])['Automobile_Sales'].mean().reset_index()
    return avg_rec_sale, avg_vehicle_type_sale, vehicle_type_advertisement, vehicle_type_unemployment

@app.callback(
    Output(component_id='output-container', component_property='children'),
    [Input(component_id='select-year', component_property='value'),
     Input(component_id='dropdown-statistics', component_property='value')]
)
def update_input_container(selected_year, selected_statistic):
    if selected_statistic == 'Yearly_Statistics':
        return get_graph(selected_year)
    elif selected_statistic == 'Recession_Period_Statistics':
        return get_recession_graph()

def get_graph(selected_year):
    avg_yearly_sales, total_monthly_sales, vehicle_sales, vehicle_advertising = compute_info(Car_sales, selected_year)

    R_chart1 = dcc.Graph(figure=px.line(avg_yearly_sales,
                                        x='Vehicle_Type',
                                        y='Automobile_Sales',
                                        title="Yearly Average Automobile sales"))
    R_chart2 = dcc.Graph(figure=px.line(total_monthly_sales,
                                        x='Month',
                                        y='Automobile_Sales',
                                        title="Total Monthly Automobile sales"))
    R_chart3 = dcc.Graph(figure=px.bar(vehicle_sales,
                                        x='Month',
                                        y='Automobile_Sales',
                                        title="Average Monthly Automobile sales"))
    R_chart4 = dcc.Graph(figure=px.pie(vehicle_advertising,
                                       values='Advertising_Expenditure',
                                       names='Vehicle_Type',
                                       title="Total Advertisement Expenditure"
                                      )
                        )

    return [
        html.Div(className='chart-item', children=[R_chart1, R_chart2]),
        html.Div(className='chart-item', children=[R_chart3, R_chart4])
    ]

def get_recession_graph():
    avg_rec_sale, avg_vehicle_type_sale, vehicle_type_advertisement, vehicle_type_unemployment = compute_recession_info(Car_sales)

    r_chart1 = dcc.Graph(figure=px.line(avg_rec_sale,
                                        x='Year',
                                        y='Automobile_Sales',
                                        title="Average Automobile sales during Recession"))
    r_chart2 = dcc.Graph(figure=px.bar(avg_vehicle_type_sale,
                                        x='Vehicle_Type',
                                        y='Automobile_Sales',
                                        title="Average number of vehicles sold during Recession"))
    r_chart3 = dcc.Graph(figure=px.bar(vehicle_type_unemployment,
                                        x='Vehicle_Type',
                                        y='Automobile_Sales',
                                        title="Effect of unemployment rate on vehicle type during Recession"))
    r_chart4 = dcc.Graph(figure=px.pie(vehicle_type_advertisement,
                                       values='Advertising_Expenditure',
                                       names='Vehicle_Type',
                                       title="Total Advertisement Expenditure during Recession"
                                      )
                        )

    return [
        html.Div(className='chart-item', children=[r_chart1, r_chart2]),
        html.Div(className='chart-item', children=[r_chart3, r_chart4])
    ]

if __name__ == '__main__':
    app.run_server()
